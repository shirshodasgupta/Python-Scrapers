# %% [markdown]
# #### Date of Scraping: April 28, 2019

# %% [markdown]
# ### Importing libraries

# %%
import requests 
from bs4 import BeautifulSoup
import time
import re
import json

# %% [markdown]
# ### Creating CSV file to be written

# %%
with open("deathlist.csv", "w") as f:
    f.write("CaseNumber,Name,BirthDate,DeathDate,Age,Gender,DeathPlace,BodyStatus,Mode,Investigator,DepMedicalExaminer,CaseStatus,Race,CauseA,CauseB,CauseC,CauseD,CauseOther,toxstatus\n" )

# %% [markdown]
# ### Defining function that starts with the first JSON file containing a list, scrapes all the details, writes it into the CSV, and moves on to the next CSV

# %%
# defining function 
def pageDetails(url):   
    # takes the URL
    page = requests.get(url)
    # takes the JSON file from the URL
    data = page.json()
    # stores the data 
    records = data["cases"]
    # loops through each entry in the JSON
    for record in records:
            # stores the case number
            casenumber = record["CaseNum"]
            # checks if the person died after 2014
            deathdate = record["DeathDate"]
            if int(deathdate[6:]) > 2014:
                time.sleep(1)
                # stores the name
                name = str(record["NameFirst"]) + " " + str(record["NameLast"])
                name = name.replace(",", "-")
                # stores the birthdate
                birthdate = record["BirthDate"]
                # stores the age 
                age = record["Age"]
                # stores the gender
                gender = record["Gender"]
                # stores the place of death
                deathplace = record["DeathPlace"].replace(",", "-")
                # stores the status of the body
                bodystatus = record["BodyStatus"].replace(",", "-")
                # stores the mode of death
                mode = record["Mode"].replace(",", "-")
                # stores the name of the primary investigator
                investigator = record["Investigator"].replace(",", "-")
                # stores the name of the deputy medical examiner
                depmedexaminer = record["DME"].replace(",", "-")
                # stores the status of the case
                casestatus = record["CaseStatus"].replace(",", "-")
                # stores URL for the JSON file that stores further details of each case
                newurl = "http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=" + str(casenumber)
                # takes the URL 
                detailpage = requests.get(newurl)
                # takes the JSON file from the URL
                detdata = detailpage.json()
                # stores the data 
                details = detdata["caseDetail"]
                # stores the race
                race = details[0]["Race"].replace(",", "-")
                # stores each cause
                causeA = details[0]["CauseA"].replace(",", "-")
                causeC = details[0]["CauseB"].replace(",", "-")
                causeB = details[0]["CauseC"].replace(",", "-")
                causeD = details[0]["CauseD"].replace(",", "-")
                causeOther = details[0]["CauseOther"].replace(",", "-")
                # stores the toxic status
                toxstatus = details[0]["ToxStatus"].replace(",", "-")
                # writes details into the CSV
                print(newurl)
                with open("deathlist.csv", "a") as f:
                            f.write(casenumber + "," + name + "," + birthdate + "," + deathdate + "," + age + "," + gender + "," + deathplace + "," + bodystatus + "," + mode + "," + investigator + "," + depmedexaminer + "," + casestatus + "," + race + "," + causeA + "," + causeB + "," + causeC + "," + causeD + "," + causeOther + "," + toxstatus + "\n") 
            else:
                break

# %% [markdown]
# ### Creating a loop that starts with the initial URL of the first JSON file and moves through each one, calling the pre-defined function and writing into the CSV

# %%
# runs through a loop that goes through each JSON file that contains lists of the dead
for offset in range(0, 1189):
    # starts with the initial loop, resetting each time reading that page is completed
    url = "http://api.lacounty.gov/mecsearch/CaseInformationServlet?pageNumber=" + str(offset) + "&pageSize=100&NameFirst=&NameLast=&BirthDate=&Age=&DeathDate=&CaseNum=&sortColumn=CaseNum&sortOrder=desc"
    # calls the function to write the details into the CSV
    print(url)
    pageDetails(url)
    time.sleep(1)
# Out:
# http://api.lacounty.gov/mecsearch/CaseInformationServlet
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09791
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09790
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09789
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09788
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09785
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09784
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09783
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09782
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09780
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09779
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09777
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09775
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09774
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09772
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09771
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09770
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09769
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09768
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09765
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09764
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09763
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09762
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09758
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09757
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09756
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09755
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09754
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09752
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09751
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09750
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09749
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09748
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09747
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09745
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09744
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09743
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09742
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09741
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09738
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09737
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09736
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09735
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09734
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09732
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09731
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09730
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09728
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09727
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09726
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09725
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09723
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09721
# http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09720
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x116585128>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Documents/jour494/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/Documents/jour494/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='api.lacounty.gov', port=80): Max retries exceeded with url: /mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09719 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x116585128>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-95-ea30ded36cf9> in <module>
#       5     # calls the function to write the details into the CSV
#       6     print(url)
# ----> 7     pageDetails(url)
#       8     time.sleep(1)
#
# <ipython-input-94-86e1dc33985e> in pageDetails(url)
#      38                 newurl = "http://api.lacounty.gov/mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=" + str(casenumber)
#      39                 # takes the URL
# ---> 40                 detailpage = requests.get(newurl)
#      41                 time.sleep(0.5)
#      42                 # takes the JSON file from the URL
#
# ~/Documents/jour494/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/Documents/jour494/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/Documents/jour494/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Documents/jour494/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Documents/jour494/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='api.lacounty.gov', port=80): Max retries exceeded with url: /mecsearch/CaseInformationServlet?caseDetails=1&CaseNum=2018-09719 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x116585128>: Failed to establish a new connection: [Errno 60] Operation timed out'))

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ### Opening the CSV file

# %%
# before importing the CSV, make sure the date is in MM/DD/YYYY format in Excel
deaths = pd.read_csv("deathlist.csv")
# displays a snapshot of the file 
deaths.head(50)
# Out:
#     CaseNumber                    Name   BirthDate   DeathDate   Age  Gender  \
# 0   2019-03294           ELLEN CAVALLI  09/02/1943  04/29/2019  75.0  FEMALE
# 1   2019-03289             PAUL DURKIN  01/16/1994  04/28/2019  25.0    MALE
# 2   2019-03284             TERRY MILLS  06/13/1952  04/28/2019  66.0    MALE
# 3   2019-03281          LORIBETH LOPEZ  07/11/1990  04/28/2019  28.0  FEMALE
# 4   2019-03279          RICARDO SEGURA  04/03/1997  04/27/2019  22.0    MALE
# 5   2019-03276  OSWALDO CORTES VASQUEZ  05/18/1978  04/27/2019  40.0    MALE
# 6   2019-03274          MELISSA CROUCH  10/21/1979  04/27/2019  39.0  FEMALE
# 7   2019-03271          RECARDO WELLER  02/03/1984  04/27/2019  35.0    MALE
# 8   2019-03265            JAMES DUARTE  03/22/1977  04/27/2019  42.0    MALE
# 9   2019-03263          DUSTIN JACKSON  03/15/1990  04/27/2019  29.0    MALE
# 10  2019-03258             ANGEL ROSAS  08/15/1980  04/26/2019  38.0    MALE
# 11  2019-03257           VICENTE LOPEZ  03/19/1962  04/26/2019  57.0    MALE
# 12  2019-03254           JOZSEF FEKETE  05/18/1966  04/26/2019  52.0    MALE
# 13  2019-03252            FELICIA PAGE  04/07/1983  04/26/2019  36.0  FEMALE
# 48  2019-03164             THOMAS WINN  06/20/1955  04/23/2019  63.0    MALE
# 49  2019-03163             SCOTT LEWIS  12/17/1956  04/23/2019  62.0    MALE
#
#                DeathPlace      BodyStatus      Mode  Investigator  \
# 0                 FREEWAY            HERE       NaN         LOPEZ
# 1               RESIDENCE            HERE       NaN     GUILMETTE
# 2               RESIDENCE            HERE       NaN         MUNOZ
# 3                  STREET            HERE       NaN      EPPERSON
# 4                 VEHICLE  EXAM SCHEDULED       NaN      REYNOLDS
# 5                HOSPITAL         TO COME       NaN       NAVARRO
# 6   SOBER LIVING FACILITY  EXAM SCHEDULED       NaN        FALLOT
# 7                  GARAGE  EXAM SCHEDULED       NaN          EARL
# 8                BUSINESS  EXAM SCHEDULED       NaN         MOSES
# 9                HOSPITAL            HERE       NaN  GRANADO-MATA
# 10                 STREET           READY  HOMICIDE      REYNOLDS
# 11               HOSPITAL            HERE       NaN            LE
# 12              RESIDENCE           READY       NaN       HERTZOG
# 13                VEHICLE  EXAM SCHEDULED       NaN        FALLOT
# 14                   ROAD           READY   SUICIDE     MCCRACKEN
# 15              RESIDENCE           READY       NaN        DEMING
# 16              RESIDENCE           READY       NaN         MOSES
# 17               BUSINESS  EXAM SCHEDULED       NaN       HERTZOG
# 18               SIDEWALK           READY       NaN        DIXSON
# 19                   PARK           READY       NaN         LOPEZ
# 20              RESIDENCE           READY       NaN      EPPERSON
# 21                FREEWAY        RELEASED  ACCIDENT        DIXSON
# 22            HOTEL/MOTEL           READY       NaN     MCCRACKEN
# 23                 GARAGE           READY   SUICIDE       HERTZOG
# 24                FREEWAY           READY  ACCIDENT        DEMING
# 25               BUSINESS           READY  ACCIDENT        FIERRO
# 26               HOSPITAL            HERE       NaN         MUNOZ
# 27               HOSPITAL           READY   NATURAL         LOPEZ
# 28              RESIDENCE           READY   NATURAL         LOPEZ
# 29               HOSPITAL           READY  ACCIDENT       NAVARRO
# 30      PRIVATE RESIDENCE           READY       NaN       MONTOYA
# 31                   YARD        RELEASED       NaN        DIXSON
# 32               HOSPITAL            HERE       NaN       NAVARRO
# 33              RESIDENCE        RELEASED   NATURAL     MCCRACKEN
# 34               HOSPITAL           READY  ACCIDENT       NAVARRO
# 35               HOSPITAL           READY  ACCIDENT          EARL
# 36              RESIDENCE           READY   NATURAL     MCCRACKEN
# 37              RESIDENCE           READY   SUICIDE       HERTZOG
# 38                VEHICLE           READY       NaN        ARNOLD
# 39                VEHICLE        RELEASED   NATURAL     BLANCHARD
# 40                  FIELD        RELEASED       NaN         MOSES
# 41                  ALLEY        RELEASED   SUICIDE         MUNOZ
# 42           HIKING TRAIL        RELEASED   SUICIDE         LOPEZ
# 43              RESIDENCE           READY   NATURAL       MONTOYA
# 44                FREEWAY           READY       NaN         LOPEZ
# 45               HOSPITAL           READY  ACCIDENT        FALLOT
# 46               HOSPITAL        RELEASED   NATURAL      EPPERSON
# 47               HOSPITAL           READY       NaN       HERTZOG
# 48               BUSINESS        RELEASED   SUICIDE  GRANADO-MATA
# 49              RESIDENCE           READY   SUICIDE        ARNOLD
#
#                       DepMedExaminer  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                     DR. AUGUSTINE
# 11                               NaN
# 12                        DR. MILLER
# 13                               NaN
# 14                          DR.YOUNG
# 15                    DR. DJABOURIAN
# 16                        DR. MILLER
# 17                               NaN
# 18                         DR. PLAZA
# 19                          DR. UKPO
# 20                        DR. MILLER
# 21                        DR. MILLER
# 22                         DR. PLAZA
# 23                        DR. MILLER
# 24                     DR. AUGUSTINE
# 25                    DR. DJABOURIAN
# 26                               NaN
# 27                     DR. AUGUSTINE
# 28  Signed by Primary Medical Doctor
# 29                          DR.YOUNG
# 30                    DR. DJABOURIAN
# 31                        DR. ASHRAF
# 32                               NaN
# 33                       DR. VALLONE
# 34                          DR.YOUNG
# 35                        DR. MILLER
# 36                       DR. VALLONE
# 37                          DR.YOUNG
# 38                    DR. DJABOURIAN
# 39                          DR.YOUNG
# 40                    DR. DJABOURIAN
# 41                          DR. WANG
# 42                        DR. NGUYEN
# 43                          DR.YOUNG
# 44                        DR. NGUYEN
# 45                          DR. UKPO
# 46                        DR. MILLER
# 47                         DR. ORTIZ
# 48                    DR. DJABOURIAN
# 49                          DR.YOUNG
#
#                                    CaseStatus                     Race  \
# 0                               INV. COMPLETE                CAUCASIAN
# 1                               INV. ASSIGNED                CAUCASIAN
# 2                               INV. ASSIGNED                CAUCASIAN
# 3                               INV. COMPLETE  HISPANIC/LATIN AMERICAN
# 4                                Exam Pending  HISPANIC/LATIN AMERICAN
# 5                               INV. COMPLETE  HISPANIC/LATIN AMERICAN
# 6                                Exam Pending                CAUCASIAN
# 7                                Exam Pending                    BLACK
# 8                                Exam Pending  HISPANIC/LATIN AMERICAN
# 9                               INV. ASSIGNED                CAUCASIAN
# 10                                     CLOSED  HISPANIC/LATIN AMERICAN
# 11                              INV. ASSIGNED                CAUCASIAN
# 12  DEFERRED Pending Additional Investigation                CAUCASIAN
# 13                               Exam Pending                    BLACK
# 14                                     CLOSED                CAUCASIAN
# 15  DEFERRED Pending Additional Investigation                CAUCASIAN
# 16  DEFERRED Pending Additional Investigation                    BLACK
# 17                               Exam Pending  HISPANIC/LATIN AMERICAN
# 18  DEFERRED Pending Additional Investigation          AMERICAN INDIAN
# 19  DEFERRED Pending Additional Investigation                    BLACK
# 20  DEFERRED Pending Additional Investigation                CAUCASIAN
# 21                                     CLOSED  HISPANIC/LATIN AMERICAN
# 22  DEFERRED Pending Additional Investigation                    ASIAN
# 23                                     CLOSED  HISPANIC/LATIN AMERICAN
# 24                                     CLOSED                CAUCASIAN
# 25                                     CLOSED                CAUCASIAN
# 26                              INV. ASSIGNED                    BLACK
# 27                                     CLOSED                CAUCASIAN
# 28                                     CLOSED                CAUCASIAN
# 29                                     CLOSED  HISPANIC/LATIN AMERICAN
# 30  DEFERRED Pending Additional Investigation                CAUCASIAN
# 31  DEFERRED Pending Additional Investigation  HISPANIC/LATIN AMERICAN
# 32                              INV. COMPLETE  HISPANIC/LATIN AMERICAN
# 33                                     CLOSED                CAUCASIAN
# 34                                     CLOSED                CAUCASIAN
# 35                                     CLOSED  HISPANIC/LATIN AMERICAN
# 36                                     CLOSED                CAUCASIAN
# 37                                     CLOSED                CAUCASIAN
# 38  DEFERRED Pending Additional Investigation  HISPANIC/LATIN AMERICAN
# 39                                     CLOSED  HISPANIC/LATIN AMERICAN
# 40  DEFERRED Pending Additional Investigation  HISPANIC/LATIN AMERICAN
# 41                                     CLOSED                    BLACK
# 42                                     CLOSED                CAUCASIAN
# 43                                     CLOSED                CAUCASIAN
# 44  DEFERRED Pending Additional Investigation                CAUCASIAN
# 45                                     CLOSED                    BLACK
# 46                                     CLOSED                    ASIAN
# 47  DEFERRED Pending Additional Investigation                CAUCASIAN
# 48                                     CLOSED                CAUCASIAN
# 49                                     CLOSED                CAUCASIAN
#
#                                              CauseA CauseB  \
# 0                                               NaN    NaN
# 1                                               NaN    NaN
# 2                                               NaN    NaN
# 3                                               NaN    NaN
# 4                                               NaN    NaN
# 5                                               NaN    NaN
# 6                                               NaN    NaN
# 7                                               NaN    NaN
# 8                                               NaN    NaN
# 9                                               NaN    NaN
# 10                                   GUNSHOT WOUNDS    NaN
# 11                                              NaN    NaN
# 12                                         DEFERRED    NaN
# 13                                              NaN    NaN
# 14                                     BLUNT TRAUMA    NaN
# 15                                         DEFERRED    NaN
# 16                                         DEFERRED    NaN
# 17                                              NaN    NaN
# 18                                         DEFERRED    NaN
# 19                                         DEFERRED    NaN
# 20                                         DEFERRED    NaN
# 21                   BLUNT FORCE TRAUMATIC INJURIES    NaN
# 22                                         DEFERRED    NaN
# 23                                          HANGING    NaN
# 24                         BLUNT TRAUMATIC INJURIES    NaN
# 25                        BLUNT CRANIOFACIAL TRAUMA    NaN
# 26                                              NaN    NaN
# 27                      SEQUELAE OF LIVER CIRRHOSIS    NaN
# 28                          CARDIOPULMONARY FAILURE    NaN
# 29                                     BLUNT TRAUMA    NaN
# 30                                         DEFERRED    NaN
# 31                                         DEFERRED    NaN
# 32                                              NaN    NaN
# 33                  SEQUELAE OF CHRONIC ETHANOL USE    NaN
# 34                               traumatic injuries    NaN
# 35                                           SEPSIS    NaN
# 36           ATHEROSCLEROTIC CARDIOVASCULAR DISEASE    NaN
# 37                   gunshot wound through the head    NaN
# 38                                         DEFERRED    NaN
# 39          ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE    NaN
# 40                                         DEFERRED    NaN
# 41                      MULTIPLE TRAUMATIC INJURIES    NaN
# 42                                 LIGATURE HANGING    NaN
# 43          ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE    NaN
# 44                                         DEFERRED    NaN
# 45  PROBABLE MIXED DRUG TOXICITY (COCAINE- ETHANOL)    NaN
# 46                     SEQUELAE OF ANOREXIA NERVOSA    NaN
# 47                                         DEFERRED    NaN
# 48                            GUNSHOT WOUND OF HEAD    NaN
# 49                                          HANGING    NaN
#
#                                     CauseC CauseD  \
# 0                                      NaN    NaN
# 1                                      NaN    NaN
# 2                                      NaN    NaN
# 3                                      NaN    NaN
# 4                                      NaN    NaN
# 5                                      NaN    NaN
# 6                                      NaN    NaN
# 7                                      NaN    NaN
# 8                                      NaN    NaN
# 9                                      NaN    NaN
# 10                                     NaN    NaN
# 11                                     NaN    NaN
# 12                                     NaN    NaN
# 13                                     NaN    NaN
# 14                                     NaN    NaN
# 15                                     NaN    NaN
# 16                                     NaN    NaN
# 17                                     NaN    NaN
# 18                                     NaN    NaN
# 19                                     NaN    NaN
# 20                                     NaN    NaN
# 21                                     NaN    NaN
# 22                                     NaN    NaN
# 23                                     NaN    NaN
# 24                                     NaN    NaN
# 25                                     NaN    NaN
# 26                                     NaN    NaN
# 27                                     NaN    NaN
# 28   MALIGNANT NEOPLASM OF ASCENDING COLON    NaN
# 29                                     NaN    NaN
# 30                                     NaN    NaN
# 31                                     NaN    NaN
# 32                                     NaN    NaN
# 33                                     NaN    NaN
# 34                                     NaN    NaN
# 35  DRUG INJECTION OF LEFT LOWER EXTREMITY    NaN
# 36                                     NaN    NaN
# 37                                     NaN    NaN
# 38                                     NaN    NaN
# 39                                     NaN    NaN
# 40                                     NaN    NaN
# 41                                     NaN    NaN
# 42                                     NaN    NaN
# 43                                     NaN    NaN
# 44                                     NaN    NaN
# 45                                     NaN    NaN
# 46                                     NaN    NaN
# 47                                     NaN    NaN
# 48                                     NaN    NaN
# 49                                     NaN    NaN
#
#                                            CauseOther      toxstatus
# 0                                                 NaN  NOT REQUESTED
# 1                                                 NaN  NOT REQUESTED
# 2                                                 NaN  NOT REQUESTED
# 3                                                 NaN  NOT REQUESTED
# 4                                                 NaN  NOT REQUESTED
# 5                                                 NaN  NOT REQUESTED
# 6                                                 NaN  NOT REQUESTED
# 7                                                 NaN  NOT REQUESTED
# 8                                                 NaN  NOT REQUESTED
# 9                                                 NaN  NOT REQUESTED
# 10                                                NaN  NOT REQUESTED
# 11                                                NaN  NOT REQUESTED
# 12                                                NaN      REQUESTED
# 13                                                NaN  NOT REQUESTED
# 14                                                NaN  NOT REQUESTED
# 15                                                NaN  NOT REQUESTED
# 16                                                NaN  NOT REQUESTED
# 17                                                NaN  NOT REQUESTED
# 18                                                NaN  NOT REQUESTED
# 19                                                NaN      REQUESTED
# 20                                                NaN      REQUESTED
# 21                                                NaN      REQUESTED
# 22                                                NaN  NOT REQUESTED
# 23                                                NaN      REQUESTED
# 24  ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE; TYPE ...  NOT REQUESTED
# 25                                                NaN  NOT REQUESTED
# 26                                                NaN  NOT REQUESTED
# 27  ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE; HISTO...  NOT REQUESTED
# 28                                                NaN  NOT REQUESTED
# 29                                                NaN  NOT REQUESTED
# 30                                                NaN  NOT REQUESTED
# 31                                                NaN      REQUESTED
# 32                                                NaN  NOT REQUESTED
# 33                                            OBESITY      REQUESTED
# 34                                                NaN  NOT REQUESTED
# 35  METHAMPHETAMINE TOXICITY- GASTROINTESTINAL HEM...  NOT REQUESTED
# 36                                                NaN      REQUESTED
# 37                                                NaN  NOT REQUESTED
# 38                                                NaN      REQUESTED
# 39                   diabetes and chronic alcohol use  NOT REQUESTED
# 40                                                NaN      REQUESTED
# 41                                                NaN      REQUESTED
# 42                                                NaN      REQUESTED
# 43                                                NaN  NOT REQUESTED
# 44                                                NaN      REQUESTED
# 45                                                NaN  NOT REQUESTED
# 46                                                NaN  NOT REQUESTED
# 47                                                NaN      REQUESTED
# 48                                                NaN      REQUESTED
# 49                                                NaN  NOT REQUESTED

# %%
# function to return new date format in YYYY-MM-DD
def DateFormat(x):
    # ensures that the data-type is a string
    x = str(x)
    newdate = x[6:] + "-" + x[:2] + "-" + x[3:][:2]
    return newdate

# %%
# creates new column with reformatted dates
deaths["DateOfDeath"] = deaths["DeathDate"].apply(lambda x: DateFormat(x))
deaths["DateOfBirth"] = deaths["BirthDate"].apply(lambda x: DateFormat(x))

# %%
deaths.head(5)
# Out:
#    CaseNumber            Name   BirthDate   DeathDate   Age  Gender  \
# 0  2019-03294   ELLEN CAVALLI  09/02/1943  04/29/2019  75.0  FEMALE
# 1  2019-03289     PAUL DURKIN  01/16/1994  04/28/2019  25.0    MALE
# 2  2019-03284     TERRY MILLS  06/13/1952  04/28/2019  66.0    MALE
# 3  2019-03281  LORIBETH LOPEZ  07/11/1990  04/28/2019  28.0  FEMALE
# 4  2019-03279  RICARDO SEGURA  04/03/1997  04/27/2019  22.0    MALE
#
#   DeathPlace      BodyStatus Mode Investigator  ...     CaseStatus  \
# 0    FREEWAY            HERE  NaN        LOPEZ  ...  INV. COMPLETE
# 1  RESIDENCE            HERE  NaN    GUILMETTE  ...  INV. ASSIGNED
# 2  RESIDENCE            HERE  NaN        MUNOZ  ...  INV. ASSIGNED
# 3     STREET            HERE  NaN     EPPERSON  ...  INV. COMPLETE
# 4    VEHICLE  EXAM SCHEDULED  NaN     REYNOLDS  ...   Exam Pending
#
#                       Race CauseA CauseB CauseC CauseD CauseOther  \
# 0                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 1                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 2                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 3  HISPANIC/LATIN AMERICAN    NaN    NaN    NaN    NaN        NaN
# 4  HISPANIC/LATIN AMERICAN    NaN    NaN    NaN    NaN        NaN
#
#        toxstatus DateOfDeath DateOfBirth
# 0  NOT REQUESTED  2019-04-29  1943-09-02
# 1  NOT REQUESTED  2019-04-28  1994-01-16
# 2  NOT REQUESTED  2019-04-28  1952-06-13
# 3  NOT REQUESTED  2019-04-28  1990-07-11
# 4  NOT REQUESTED  2019-04-27  1997-04-03
#
# [5 rows x 21 columns]

# %%
# saving as file
deaths.to_csv("newdeathlist.csv", index=False)

# %%
# imports file with the new date format
newdeaths = pd.read_csv("newdeathlist.csv")

# %%
newdeaths.head(5)
# Out:
#    CaseNumber            Name   BirthDate   DeathDate   Age  Gender  \
# 0  2019-03294   ELLEN CAVALLI  09/02/1943  04/29/2019  75.0  FEMALE
# 1  2019-03289     PAUL DURKIN  01/16/1994  04/28/2019  25.0    MALE
# 2  2019-03284     TERRY MILLS  06/13/1952  04/28/2019  66.0    MALE
# 3  2019-03281  LORIBETH LOPEZ  07/11/1990  04/28/2019  28.0  FEMALE
# 4  2019-03279  RICARDO SEGURA  04/03/1997  04/27/2019  22.0    MALE
#
#   DeathPlace      BodyStatus Mode Investigator  ...     CaseStatus  \
# 0    FREEWAY            HERE  NaN        LOPEZ  ...  INV. COMPLETE
# 1  RESIDENCE            HERE  NaN    GUILMETTE  ...  INV. ASSIGNED
# 2  RESIDENCE            HERE  NaN        MUNOZ  ...  INV. ASSIGNED
# 3     STREET            HERE  NaN     EPPERSON  ...  INV. COMPLETE
# 4    VEHICLE  EXAM SCHEDULED  NaN     REYNOLDS  ...   Exam Pending
#
#                       Race CauseA CauseB CauseC CauseD CauseOther  \
# 0                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 1                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 2                CAUCASIAN    NaN    NaN    NaN    NaN        NaN
# 3  HISPANIC/LATIN AMERICAN    NaN    NaN    NaN    NaN        NaN
# 4  HISPANIC/LATIN AMERICAN    NaN    NaN    NaN    NaN        NaN
#
#        toxstatus DateOfDeath DateOfBirth
# 0  NOT REQUESTED  2019-04-29  1943-09-02
# 1  NOT REQUESTED  2019-04-28  1994-01-16
# 2  NOT REQUESTED  2019-04-28  1952-06-13
# 3  NOT REQUESTED  2019-04-28  1990-07-11
# 4  NOT REQUESTED  2019-04-27  1997-04-03
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Filters for deaths in schools

# %%
schooldeaths = newdeaths[newdeaths["DeathPlace"] == "SCHOOL/ COLLEGE"]

# %%
schooldeaths.shape
# Out:
# (32, 21)

# %%
schooldeaths
# Out:
#        CaseNumber                   Name   BirthDate   DeathDate   Age  \
# 400    2019-02577  SANDRA MENDOZA MUNGIA  07/27/1967  04/01/2019  51.0
# 951    2019-01649            ERIC CRAMER  04/23/1996  02/26/2019  22.0
# 1092   2019-01404        JEREMY PETERSON  06/27/1996  02/19/2019  22.0
# 1470   2019-00856          GERALD MCKEON  05/17/1947  01/31/2019  71.0
# 2382   2018-09353       DOUGLAS CAMPBELL  01/18/1972  12/09/2018  46.0
# 2835   2018-08670    JESUS  LOPEZ PULIDO  06/15/1955  11/14/2018  63.0
# 3771   2018-07281             KEVIN KING  06/05/1994  09/20/2018  24.0
# 4131   2018-06746         LAWRENCE VUONG  12/01/1999  08/31/2018  18.0
# 5398   2018-04790        DANIEL CALLAHAN  07/13/1963  06/23/2018  54.0
# 5614   2018-04399   FRANCISCO PENADO JR.  11/03/1973  06/09/2018  44.0
# 6749   2018-02688         MCKENNA MARTIN  07/23/1998  04/04/2018  19.0
ALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE          LEE  ...
# 12506    MALE  SCHOOL/ COLLEGE      READY       NATURAL    BLACKLOCK  ...
# 13519  FEMALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE      NAVARRO  ...
# 13977    MALE  SCHOOL/ COLLEGE      READY      ACCIDENT      SALGADO  ...
# 14127    MALE  SCHOOL/ COLLEGE      READY      ACCIDENT       NELSON  ...
# 15110    MALE  SCHOOL/ COLLEGE   RELEASED      HOMICIDE       GADSON  ...
# 15751    MALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE        WEBER  ...
# 18357    MALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE        GODOY  ...
# 18391    MALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE          KIM  ...
# 18392    MALE  SCHOOL/ COLLEGE   RELEASED      HOMICIDE          KIM  ...
# 20269  FEMALE  SCHOOL/ COLLEGE      READY  UNDETERMINED       CRONIN  ...
# 21996    MALE  SCHOOL/ COLLEGE   RELEASED       SUICIDE    MAGDALENO  ...
# 23780    MALE  SCHOOL/ COLLEGE   RELEASED      HOMICIDE       DIXSON  ...
# 24274    MALE  SCHOOL/ COLLEGE      READY      ACCIDENT        LOPEZ  ...
#
#                                       CaseStatus                     Race  \
# 400    DEFERRED Pending Additional Investigation                CAUCASIAN
# 951                                       CLOSED                CAUCASIAN
# 1092                                      CLOSED                    ASIAN
# 1470                                      CLOSED                CAUCASIAN
# 2382                                      CLOSED                CAUCASIAN
# 2835                                      CLOSED  HISPANIC/LATIN AMERICAN
# 3771                                      CLOSED  HISPANIC/LATIN AMERICAN
# 4131                                      CLOSED                    ASIAN
# 5398                                      CLOSED                CAUCASIAN
# 5614                                      CLOSED  HISPANIC/LATIN AMERICAN
# 6749                                      CLOSED                CAUCASIAN
# 8063                                      CLOSED                    BLACK
# 8808                                      CLOSED                   KOREAN
# 9232                                      CLOSED  HISPANIC/LATIN AMERICAN
# 10613                                     CLOSED                CAUCASIAN
# 10624                                     CLOSED                CAUCASIAN
# 10804                                     CLOSED  HISPANIC/LATIN AMERICAN
# 10833                                     CLOSED                    BLACK
# 10900                                     CLOSED                CAUCASIAN
# 12506                                     CLOSED  HISPANIC/LATIN AMERICAN
# 13519                                     CLOSED                    BLACK
# 13977                                     CLOSED  HISPANIC/LATIN AMERICAN
# 14127                                     CLOSED                CAUCASIAN
# 15110                                     CLOSED                  CHINESE
# 15751                                     CLOSED                CAUCASIAN
# 18357                                     CLOSED                CAUCASIAN
# 18391                                     CLOSED                    ASIAN
# 18392                                     CLOSED                CAUCASIAN
# 20269                                     CLOSED                CAUCASIAN
# 21996                                     CLOSED                    ASIAN
# 23780                                     CLOSED                CAUCASIAN
# 24274                                     CLOSED  HISPANIC/LATIN AMERICAN
#
#                                                   CauseA  \
# 400                                             DEFERRED
# 951                                GUNSHOT WOUND TO HEAD
# 1092   COMBINED EFFECTS OF FENTANYL INTOXICATION AND ...
# 1470                               MYOCARDIAL INFARCTION
# 2382                               GUNSHOT WOUND OF HEAD
# 2835                     CORONARY ARTERY ATHEROSCLEROSIS
# 3771                               GUNSHOT WOUND OF HEAD
# 4131                           GUNSHOT WOUND OF THE HEAD
# 5398                          GUNSHOT WOUND OF THE CHEST
# 5614                           GUNSHOT WOUND OF THE HEAD
# 6749                                            HANGING
# 8063                                           PNEUMONIA
# 8808                                 CEREBRAL HEMORRHAGE
# 9232                       ATHEROSCLEROTIC HEART DISEASE
# 10613                               SUDDEN CARDIAC DEATH
# 10624                  EFFECTS OF   CYCLOPROPYL FENTANYL
# 10804                                  CARDIAC TAMPONADE
# 10833                      ATHEROSCLEROTIC HEART DISEASE
# 10900                                 BLUNT FORCE TRAUMA
# 12506            ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE
# 13519                                           ASPHYXIA
# 13977                          SYNTHETIC OPIOID TOXICITY
# 14127                SUDDEN UNEXPECTED DEATH IN EPILEPSY
# 15110                               SHARP FORCE INJURIES
# 15751                      MULTIPLE BLUNT FORCE INJURIES
# 18357                                            HANGING
# 18391                              GUNSHOT WOUND OF HEAD
# 18392                            MULTIPLE GUNSHOT WOUNDS
# 20269  UNDETERMINED AFTER AUTOPSY AND TOXICOLOGY STUD...
# 21996                        MULTIPLE TRAUMATIC INJURIES
# 23780                         GUNSHOT WOUND OF RIGHT ARM
# 24274            ATHEROSCLEROTIC CORONARY ARTERY DISEASE
#
#                                         CauseB  \
# 400                                        NaN
# 951                                        NaN
# 1092                                       NaN
# 1470   ARTERIOSCLEROTIC CARDIOVASCULAR DISEASE
# 2382                                       NaN
# 2835                                       NaN
# 3771                                       NaN
# 4131                                       NaN
# 5398                                       NaN
# 5614                                       NaN
# 6749                                       NaN
# 8063                                       NaN
# 8808                                       NaN
# 9232                                       NaN
# 10613                                      NaN
# 10624                                      NaN
# 10804                                      NaN
# 10833                                      NaN
# 10900                                      NaN
# 12506                                      NaN
# 13519                                      NaN
# 13977                                      NaN
# 14127                                      NaN
# 15110                                      NaN
# 15751                                      NaN
# 18357                                      NaN
# 18391                                      NaN
# 18392                                      NaN
# 20269                                      NaN
# 21996                                      NaN
# 23780                                      NaN
# 24274                                      NaN
#
#                                                CauseC CauseD  \
# 400                                               NaN    NaN
# 951                                               NaN    NaN
# 1092                                              NaN    NaN
# 1470   THROMBOSIS OF RIGHT AND LEFT CORONARY ARTERIES    NaN
# 2382                                              NaN    NaN
# 2835           ATHEROSCLEROTIC CARDIOVASCULAR DISEASE    NaN
# 3771                                              NaN    NaN
# 4131                                              NaN    NaN
# 5398                                              NaN    NaN
# 5614                                              NaN    NaN
# 6749                                              NaN    NaN
# 8063                                              NaN    NaN
# 8808                                              NaN    NaN
# 9232                                              NaN    NaN
# 10613          ATHEROSCLEROTIC CARDIOVASCULAR DISEASE    NaN
# 10624                                             NaN    NaN
# 10804   DISSECTING  HEMORRHAGE OF THE ASCENDING AORTA    NaN
# 10833                                             NaN    NaN
# 10900                                             NaN    NaN
# 12506                                             NaN    NaN
# 13519                                             NaN    NaN
# 13977                                             NaN    NaN
# 14127                                             NaN    NaN
# 15110                                             NaN    NaN
# 15751                                             NaN    NaN
# 18357                                             NaN    NaN
# 18391                                             NaN    NaN
# 18392                                             NaN    NaN
# 20269                                             NaN    NaN
# 21996                                             NaN    NaN
# 23780                                             NaN    NaN
# 24274                                             NaN    NaN
#
#                                               CauseOther      toxstatus  \
# 400                                                  NaN      REQUESTED
# 951                                     BIPOLAR DISORDER      REQUESTED
# 1092                          HYPERTROPHIC HEART DISEASE      REQUESTED
# 1470                                                 NaN      REQUESTED
# 2382                                                 NaN      REQUESTED
# 2835   DIABETES MELLITUS AND DILATED CARDIOMYOPATHY D...      REQUESTED
# 3771                                                 NaN      REQUESTED
# 4131                                                 NaN      REQUESTED
# 5398                                                 NaN      REQUESTED
# 5614                                                 NaN      REQUESTED
# 6749                                                 NaN      REQUESTED
# 8063                               CHRONIC ALCOHOL ABUSE      REQUESTED
# 8808                          HYPERTROPHIC HEART DISEASE  NOT REQUESTED
# 9232             DIABETES- MELLITUS- IDIOPATHIC EPILEPSY  NOT REQUESTED
# 10613                                            OBESITY  NOT REQUESTED
# 10624                                                NaN      REQUESTED
# 10804                                                NaN      REQUESTED
# 10833                                                NaN      REQUESTED
# 10900                                                NaN  NOT REQUESTED
# 12506                                                NaN  NOT REQUESTED
# 13519                                                NaN      REQUESTED
# 13977                                                NaN      REQUESTED
# 14127                                     COCAINE INTAKE      REQUESTED
# 15110                                                NaN      REQUESTED
# 15751                                                NaN      REQUESTED
# 18357                                                NaN      REQUESTED
# 18391                                                NaN      REQUESTED
# 18392                                                NaN      REQUESTED
# 20269                                                NaN      REQUESTED
# 21996                                                NaN  NOT REQUESTED
# 23780                                                NaN      REQUESTED
# 24274                                       ETHANOL USE       REQUESTED
#
#       DateOfDeath DateOfBirth
# 400    2019-04-01  1967-07-27
# 951    2019-02-26  1996-04-23
# 1092   2019-02-19  1996-06-27
# 1470   2019-01-31  1947-05-17
# 2382   2018-12-09  1972-01-18
# 2835   2018-11-14  1955-06-15
# 3771   2018-09-20  1994-06-05
# 4131   2018-08-31  1999-12-01
# 5398   2018-06-23  1963-07-13
# 5614   2018-06-09  1973-11-03
# 6749   2018-04-04  1998-07-23
# 8063   2018-01-16  1961-08-16
# 8808   2017-12-08  1969-02-02
# 9232   2017-11-14  1958-01-27
# 10613  2017-08-24  1949-07-21
# 10624  2017-08-23  1993-05-08
# 10804  2017-08-11  1958-06-07
# 10833  2017-08-09  1986-07-23
# 10900  2017-08-06  1945-01-12
# 12506  2017-05-05  1977-03-18
# 13519  2017-03-04  1996-04-14
# 13977  2017-02-02  1995-04-05
# 14127  2017-01-25  1995-01-29
# 15110  2016-12-02  1966-01-21
# 15751  2016-10-28  1953-04-01
# 18357  2016-06-03  1937-11-01
# 18391  2016-06-01  1977-06-16
# 18392  2016-06-01  1976-06-19
# 20269  2016-02-11  1996-01-04
# 21996  2015-10-31  1993-10-31
# 23780  2015-07-18  1991-08-24
# 24274  2015-06-20  1953-08-08
#
# [32 rows x 21 columns]
